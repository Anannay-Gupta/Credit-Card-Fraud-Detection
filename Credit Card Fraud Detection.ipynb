# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
cc_data = pd.read_csv('creditcard.csv')

# %%
#Elapsed Time First Column
#Amount is in US Dollars
cc_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
cc_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
cc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#check the number of missing values in each column
cc_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transaction(0) and fraudalent transaction(1)
cc_data['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#This dataset is highly unbalanced as label 0(normal transactions) 
#is almost more than 99% of data hence we can't put the data in our model like this so we will need to do some preprocessing.

# %%
legit = cc_data[cc_data.Class==0]
fraud = cc_data[cc_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#statiscal meseaures of the data

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#for all the fraud activities the mean Amount is more than legit activities.

# %%
#Compare the values for both transactions
cc_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Under-Sampling
#Here we will build a sample dataset from the original dataset containing 
#similliar distribution of normal transactions and fraudalent transactions.
#Number of fraudalent transactions -> 492.

# %%
legit_sample = legit.sample(n=492)#will take random 492 legit values

# %%
#Now we will concatenate two df's the fraudalent one and the new random legit one(legit sample)
new_data = pd.concat([legit_sample,fraud],axis = 0)

# %%
new_data.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 252233  155715.0  1.547389 -1.208744 -0.572950  0.400351 -1.018146 -0.508847
# 17813    28935.0 -0.684161  0.515467  2.110644  1.669266 -0.534963  0.288704
# 82390    59382.0  1.051054 -0.756808  0.645284  0.418476 -0.909144  0.440382
# 87504    61715.0 -2.380021 -1.268134  1.478371 -2.066850  0.107836 -0.678986
# 96207    65659.0 -5.576185 -6.435046  2.438557  1.537200  4.856318 -1.706491
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 252233 -0.299318 -0.146348  1.451966  ...  0.316743  0.652080 -0.094001
# 17813   0.349257  0.125496  0.169337  ...  0.078453  0.616318  0.060604
# 82390  -0.753933  0.230575 -0.953712  ... -0.132293 -0.121654 -0.090483
# 87504  -0.528725  0.630468  1.632769  ...  0.186866  0.290624 -0.320215
# 96207  -3.693940  0.961225  0.886634  ...  0.218604  0.004756  1.031994
#
# ...

# %%
new_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 279863 -0.882850  0.697211 -2.064945  ...  0.778584 -0.319189  0.639419
# 280143 -1.413170  0.248525 -1.127396  ...  0.370612  0.028234 -0.145640
# 280149 -2.234739  1.210158 -0.652250  ...  0.751826  0.834108  0.190944
# 281144 -2.208002  1.058733 -1.632333  ...  0.583276 -0.269209 -0.456108
# 281674  0.223050 -0.068384  0.577829  ... -0.164350 -0.295135 -0.072173
#
# ...

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97180.571138  0.024963  0.028213  0.010116 -0.025474  0.009581
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.082074 -0.013622  0.011249  0.025471  ... -0.017988  0.045569
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.001679  0.056317  0.040653 -0.015093 -0.005547  0.033490  0.011007
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       84.926423
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#It shows that the distance is still there in the new dataset between both fraud and legit transactions hence good dataset.
#Very important to check whether we got a good sample or bad sample.

# %%
X = new_data.drop(columns = 'Class',axis = 1)
Y = new_data['Class']

# %%
print(X)# Now we dont have our class column in the dataset
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 252233  155715.0  1.547389 -1.208744 -0.572950  0.400351 -1.018146 -0.508847
# 17813    28935.0 -0.684161  0.515467  2.110644  1.669266 -0.534963  0.288704
# 82390    59382.0  1.051054 -0.756808  0.645284  0.418476 -0.909144  0.440382
# 87504    61715.0 -2.380021 -1.268134  1.478371 -2.066850  0.107836 -0.678986
# 96207    65659.0 -5.576185 -6.435046  2.438557  1.537200  4.856318 -1.706491
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
print(Y) # the class column is stored here in Y
# Out:
# 252233    0
# 17813     0
# 82390     0
# 87504     0
# 96207     0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
#now split the data into testing and training data.

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,stratify = Y,random_state = 2)

# %%
print(X_train.shape,X_test.shape) #80% of data goes in X_train and 20% into X_test
# Out:
# (787, 30) (197, 30)

# %%
#logisticRegressiontraining
model = LogisticRegression(max_iter=1000)

# %%
#training logisticregression model with training data
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline

scaler = StandardScaler()
model = LogisticRegression(max_iter=1000)
pipeline = make_pipeline(scaler, model)

pipeline.fit(X_train, Y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression(max_iter=1000))])

# %%
#Model Evaluation

# %%
#Based on Accuracy Score (Accuracy on training data)
X_train_pred = pipeline.predict(X_train)  #predicting labels for training data
training_data_accuracy = accuracy_score(X_train_pred,Y_train) #and then comparing them to original values in Y_train
print('Accuracy on training data: ',training_data_accuracy)
# Out:
# Accuracy on training data:  0.9529860228716646

# %%
#we got accuracy score of 95.2%

# %%
X_test_pred = pipeline.predict(X_test)
test_data_accuracy = accuracy_score(X_test_pred,Y_test)
print('Accuracy on test data: ',test_data_accuracy)
# Out:
# Accuracy on test data:  0.9187817258883249

# %%
#the score is 91.87%
